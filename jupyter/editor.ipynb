# %% [markdown]
# 空的ipynb文件, 主要是为了可视化 Markdown 编辑器, 支持实时预览和各种扩展功能, 主要是为了能让用户不需要下载库, 在 web 上就可以编辑代码

# %% [markdown]
# 行内公式: $E = mc^2$
#
# 行间公式:
#
# $$
# \begin{bmatrix}
# a & b \\
# c & d
# \end{bmatrix}
# $$
#
# codeblock
#
# ```js
# function hello() {
#   console.log("Hello, Jupyter!");
# }
# ```

# %%
print('hello, world')
